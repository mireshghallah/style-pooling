# %%
import json
from collections import defaultdict
import matplotlib.pyplot as plt
import re
import sys
import subprocess

# %%
def make_doc_command(step, dire):

    com = r"""../scripts/post_process_metrics.py 
            --input_ood ../data/multi_domain_renamed/dev.txt
            --dom_file ../data/multi_domain_renamed/dev.attr
            --vocab ../data/multi_domain_renamed/domains.vocab
            --input_translated ../{}/dev.trans_{}""".format(dire, step)
    return com

#print (proc.communicate())

# %%
val_step =[]
classifier_acc = []
n_acc = []
bt_acc = []
total_loss=[]
neg_ELBO = []
KL_loss=[]
bleu = []

corr_ratio=[]
remain_ratio=[]
remov_ratio=[]
spread_ratio=[]

log_paths=[
"path to checkpoint"
]
for log_path in log_paths:   
    with open("../"+log_path+"/stdout") as f:
        val_step =[]
        classifier_acc = []
        n_acc = []
        bt_acc = []
        total_loss=[]
        neg_ELBO = []
        KL_loss=[]
        bleu = []

        corr_ratio=[]
        remain_ratio=[]
        remov_ratio=[]
        spread_ratio=[]
        for i, line in enumerate(f):
            if ("classifier_acc_negate_true=" in line):
                list_acc = re.findall("\d+\.\d+", line)
                #print(list_acc)
                classifier_acc.append(float(list_acc[0])*100)
            elif ("BLEU" in line):
                list_bleu = re.findall("\d+\.\d+", line)
                bleu.append(float(list_bleu[-1]))
            elif ("val_step" in line):
                list_arguments = re.findall(r"[-+]?\d*\.\d+|\d+", line)
                #print(list_arguments)
                if (int(list_arguments[0])>40000):
                    break
                val_step.append(int(list_arguments[0]))
                total_loss.append(float(list_arguments[1]))
                neg_ELBO.append(float(list_arguments[2]))
                KL_loss.append(float(list_arguments[3]))
                n_acc.append(float(list_arguments[6])*100)
                bt_acc.append(float(list_arguments[7])*100)
                ###get acc nums
                com = make_doc_command(str(val_step[-1]),log_path)
                proc = subprocess.Popen(["/home/NAME/anaconda3/envs/py37/bin/python"]+(com.replace('\n','').split()), stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
                outp = (proc.communicate())
                #print(outp)
                
                list_arguments = re.findall(r"[-+]?\d*\.\d+|\d+", str(outp[0]))

                corr_ratio.append(float(list_arguments[-4]))
                remain_ratio.append(float(list_arguments[-3]))
                remov_ratio.append(float(list_arguments[-2]))
                spread_ratio.append(float(list_arguments[-1]))
        #print("=SPLIT(\""+','.join([str(i) for i in val_step])+"\",\",\")")
        
        print("=SPLIT(\""+','.join([str(i) for i in bt_acc])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in corr_ratio])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in remain_ratio])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in remov_ratio])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in spread_ratio])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in classifier_acc])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in KL_loss])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in bleu])+"\",\",\")")
        print("=SPLIT(\""+','.join([str(i) for i in n_acc])+"\",\",\")")
        #print("=SPLIT(\""+','.join([str(i*100) for i in sum_doc])+"\",\",\")")
        #print("=SPLIT(\""+','.join([str(i*100) for i in maj_doc])+"\",\",\")")
        #print("=SPLIT(\""+','.join([str(i*100) for i in cls_sent])+"\",\",\")")
        print("********************")

                
            


print(len(val_step), len(n_acc), len(bt_acc))
# Out:
# =SPLIT("81.0,92.67,95.12,93.12,68.22,80.94,82.83,78.16,78.82000000000001,79.17",",")
# =SPLIT("65.2104377104377,99.30976430976432,98.35858585858585,84.67171717171718,43.30808080808081,54.503367003366996,57.31481481481482,46.792929292929294,47.63468013468014,48.678451178451176",",")
# =SPLIT("33.91414141414141,0.4966329966329966,1.5993265993265993,0.08417508417508417,1.4730639730639732,0.1851851851851852,0.260942760942761,0.0,0.0,0.008417508417508417",",")
# =SPLIT("0.8754208754208754,0.1936026936026936,0.04208754208754208,15.244107744107744,55.218855218855225,45.31144781144781,42.42424242424242,53.207070707070706,52.36531986531987,51.31313131313131",",")
# =SPLIT("0.2378461825102141,0.0735683581533384,1.02620656499115,0.04762546412744041,2.0236255839022634,0.188166247454785,0.2740181791565191,0.0,0.0,0.0",",")
# =SPLIT("44.943333333333335,33.49666666666667,33.413333333333334,33.403333333333336,33.416666666666664,33.43333333333333,33.48,33.45666666666667,33.43666666666667,33.45",",")
# =SPLIT("8.52,8.8,8.68,8.63,8.38,8.28,8.21,8.09,8.08,8.09",",")
# =SPLIT("44.9,79.32,91.25,86.92,37.93,62.61,65.7,55.75,56.7,57.96",",")
# =SPLIT("66.97999999999999,71.61999999999999,72.8,74.03999999999999,74.77000000000001,76.55999999999999,76.91,77.38000000000001,77.56,77.71000000000001",",")
# ********************
# =SPLIT("82.50999999999999,90.89,95.23,95.88,81.15,79.29,73.41,72.43,72.11,70.09",",")
# =SPLIT("60.95959595959596,98.31649831649831,99.33501683501683,98.3922558922559,55.54713804713805,47.54208754208754,33.543771043771045,31.574074074074076,30.799663299663298,27.13804713804714",",")
# =SPLIT("37.17171717171717,1.5151515151515151,0.563973063973064,0.2861952861952862,0.31986531986531985,0.2946127946127946,0.6481481481481481,0.04208754208754208,0.016835016835016835,0.04208754208754208",",")
# =SPLIT("1.8686868686868685,0.16835016835016833,0.10101010101010101,1.3215488215488216,44.13299663299664,52.16329966329967,65.8080808080808,68.38383838383838,69.18350168350167,72.81986531986531",",")
# =SPLIT("0.08416177586138061,0.1606928973529764,0.06597097456781251,0.10607640968312906,0.19955982752425439,0.2289712008091455,0.4899838303988502,0.04080744866317989,0.011950865705806418,0.02745006055282735",",")
# =SPLIT("46.17666666666666,33.806666666666665,33.50666666666667,33.403333333333336,33.76,33.72666666666667,33.88333333333333,33.79,33.903333333333336,33.78333333333333",",")
# =SPLIT("8.92,8.62,8.67,8.74,8.33,8.31,8.37,8.26,8.14,8.18",",")
# =SPLIT("46.34,76.58,90.39,92.11,64.06,56.78,44.77,42.54,41.38,36.32",",")
# =SPLIT("66.41,71.17999999999999,73.21,73.72,74.87,76.37,77.21000000000001,77.53999999999999,77.59,77.83",",")
# ********************
# =SPLIT("78.97999999999999,90.24,82.69999999999999,82.58,73.91,79.33,75.27000000000001,74.74",",")
